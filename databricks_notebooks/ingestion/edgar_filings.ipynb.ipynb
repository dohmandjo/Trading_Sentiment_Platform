# %%
# create a spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("trading_sentiment_platform").getOrCreate()

# %% [markdown]
# ## Create a delta table with all 10-Ks or 10-Qs filings

# %%
# SEC files modeling schema
from pyspark.sql.types import StructType, StructField, StringType, DateType

raw_filings_schema = StructType ([
    StructField("cik", StringType(), True),
    StructField("company_name", StringType(), True),
    StructField("tickers", StringType(), True),
    StructField("form_type", StringType(), True),
    StructField("filing_date", DateType(), True),
    StructField("accessionNumber", StringType(), True),
    StructField("filing_url", StringType(), True)
])

# %% [markdown]
# ##### Extract all CIKs available from SEC EDGAR lookup data (10-Ks and 10-Qs)

# %%
import requests
import pandas as pd
from io import StringIO
from pyspark.sql import functions as F
import re

# SEC header (they block generic user-agents)
headers = {"User-Agent": "Joel Doh joeljuniordoh19@gmail.com"}

# Download the mapping file
url = "https://www.sec.gov/Archives/edgar/cik-lookup-data.txt"
try:    text = requests.get(url, headers=headers).text
except Exception as e:
    print(f"Error fetching data: {e}")
    text = ""


# split the text into lines and store them in a list 
lines = [line for line in text.splitlines()]

# Split company names and CIKs, and extract the CIKs using regex
sec_ciks = []
for line in lines:
    match = re.match(r"^(.*?):(\d{7,}):$", line)
    if match:
        cik = match.group(2).strip()
        sec_ciks.append(cik)

# Create a DataFrame for the ciks
company_cik = pd.DataFrame(sec_ciks, columns=["cik"])
# company_cik.count()
print(len(sec_ciks))

# %% [markdown]
# ##### Filter the CIKs of those companies that filed 10-K or 10-Q files only by batches

# %%
# loop through the list of extracted CIKs using the index in the indicated range
def get_qualified_ciks(start, end, cik_list):
    import requests
    from pyspark.sql.types import StructType, StructField, StringType

    headers = {"User-Agent": "Joel Doh joeljuniordoh19@gmail.com"}

    results = []
    for i in range(start, end):
        try:
            url = f"https://data.sec.gov/submissions/CIK{cik_list[i]}.json"
            resp = requests.get(url, headers=headers, timeout=10)
            if resp.status_code != 200:
                continue

            data = resp.json()
            forms = data.get("filings", {}).get("recent", {}).get("form", [])

            # check if any form is 10-K or 10-Q
            if any(f in ("10-K", "10-Q") for f in forms):
                results.append({
                    "cik": data.get("cik")
                })
                print(f"{i}:{cik_list[i]}")
        
        except Exception as e:
            print(f"Error checking CIK {cik_list[i]}: {e}")
            continue

    schema = T.StructType([T.StructField("cik", T.StringType(), True)])
    return spark.createDataFrame(results, schema)

# process by batches 

# 1st batch in the list qualified was from range 0-600000
ciks_part1 = get_qualified_ciks(0, 600000, sec_ciks)
# 2nd batch in the list qualified was from range 600000-900000
ciks_part2 = get_qualified_ciks(60000, 900000, sec_ciks)
# 3rd batch in the list qualified was from range 900000-len(sec_ciks)
ciks_part3 = get_qualified_ciks(900000, len(sec_ciks), sec_ciks)

# %%
# # convert the qualified ciks lists into dataframes
# ciks_part1 = spark.createDataFrame(qualified_part1).distinct() 
# ciks_part2 = spark.createDataFrame(qualified_part2).distinct() 
# ciks_part3 = spark.createDataFrame(qualified_part3).distinct()

# %%
# save each dataframe in delta tables
# ciks_part1.write.format("delta").mode("overwrite").saveAsTable("sec_filings.ciks_part1")
# ciks_part2.write.format("delta").mode("overwrite").saveAsTable("sec_filings.ciks_part2")
# ciks_part3.write.format("delta").mode("overwrite").saveAsTable("sec_filings.ciks_part3")

# %% [markdown]
# ##### Unify the separate CIKs tables into one CIKs table

# %%
# load all the ciks tables from delta into dataframes
ciks_part1 = spark.read.table("sec_filings.cik_part1").distinct()
ciks_part2 = spark.read.table("sec_filings.cik_part2").distinct()
ciks_part3 = spark.read.table("sec_filings.ciks_part3").distinct()

# join them in one dataframe
ciks = (ciks_part1
              .unionByName(ciks_part2)
              .unionByName(ciks_part3)
              .distinct())

# rename the "_1" column to "cik"
ciks = ciks.withColumnRenamed("_1", "cik")


display(ciks)
ciks.count()

# %%
# save all qualified CIKs into a new delta table
ciks.write.format("delta").mode("overwrite").saveAsTable("sec_filings.all_qualified_ciks")

# %% [markdown]
# #### Extract 10-Ks and 10-Qs filing URLs and other relevant data using the unified CIKs table

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T
from datetime import datetime, timedelta
import requests

headers = {"User-Agent": "joel doh joeljuniordoh19@gmail.com"}

# define a function that returns the primary ticker
def get_primary_ticker(tickers):

    if not tickers or len(tickers) == 0:
        return None
    if len(tickers) == 1:
        return tickers[0]
    
    return sorted(tickers)[0]

# define a function that takes a list of qualified ciks and returns their data 
def get_filing_data_df(ciks, schema):
    records = []
    for i in range(len(ciks)):
        try: 
            # request data from the url
            url = f"https://data.sec.gov/submissions/CIK{ciks[i]}.json"
            # print(f"{i}:{url}")
            response = requests.get(url, headers=headers)
            
            # gets data if the request went through and append them in rows to the records list
            if response.status_code == 200:
                response = response.json()
                recent = response["filings"]["recent"]
                for i in range(len(recent["accessionNumber"])):
                    form = recent["form"][i]
                    date = recent["filingDate"][i]

                    five_years_ago = datetime.now() - timedelta(days=5*365)
                    date_obj = datetime.strptime(date, "%Y-%m-%d")

                    # only takes forms 10-K or 10-Q in the past five years
                    if form in ["10-K", "10-Q"] and date_obj>=five_years_ago:
                        acc = recent["accessionNumber"][i]
                        doc = recent["primaryDocument"][i]
                        file_url = f"https://www.sec.gov/Archives/edgar/data/{int(response['cik'])}/{acc.replace('-', '')}/{doc}"
                        # print(file_url)
                        records.append({
                            "cik": response["cik"],
                            "company_name": response["name"],
                            "tickers": get_primary_ticker(response["tickers"]),
                            "form_type": form,
                            "filing_date": date_obj.date(),
                            "accessionNumber": acc,
                            "filing_url": file_url
                        })
            else:
                print(f"Request failed: {response.status_code}")
        except Exception as e:
            print(f"No file: {e}")

    return spark.createDataFrame(records, schema)
# print(records[1]["accessionNumber"])
cik_list = [row["cik"]for row in ciks.collect()]
sec_filings_df = get_filing_data_df(cik_list, raw_filings_schema)
display(sec_filings_df.limit(5))

# %%
# save extracted filings data in a table
sec_filings_df.write.format("delta").mode("overwrite").saveAsTable("sec_filings.raw_filing_doc")

# %% [markdown]
# ### Filter top 100 companies by market cap

# %%
# load companies filing data and get the tickers 
from pyspark.sql import functions as F

sec_filings_df = spark.read.table("workspace.sec_filings.raw_filing_doc")
sec_tickers = sec_filings_df.where(F.col("tickers").isNotNull())
tickers = sec_tickers.select("tickers").distinct()
print(sec_tickers.count())
print(tickers.count())

# %%
# install yahoo finance package
# %pip install yfinance

# %%
# %restart_python

# %% [markdown]
# ##### Define a function that gets the market cap of each company and their sector using yahoo finance

# %%
def get_ymarket_cap(cik_df, start, end):
    import yfinance as yf
    from pyspark.sql.types import StructField, StringType, StructType, IntegerType, LongType

    tickers = [row['tickers'] for row in cik_df.select('tickers').dropna().distinct().collect()]
    print(tickers)
    market_data = []

    for i in range(start, end):
        try:
            info = yf.Ticker(tickers[i]).info

            print(f"{i}: {tickers[i]} - {info.get("marketCap", None)}")
            market_data.append({
                "tickers": tickers[i],
                "market_cap": info.get("marketCap", None),
                "sector": info.get("sector", None)
            })
        except Exception as e:
            print(f"No ticker {i}-{tickers[i]}: {e}")

    schema = StructType([
        StructField("tickers", StringType(), True),
        StructField("market_cap", LongType(), True),
        StructField("sector", StringType(), True)
    ])
    return spark.createDataFrame(market_data, schema)
# display(market_trend1.limit(5))

# %% [markdown]
# ##### Process the tickers by batches (Yahoo finance pull limit about 1000 every 15 minutes)

# %%
distinct_tickers = sec_filings_df.select("tickers").dropna().distinct()

market_trend1 = get_ymarket_cap(sec_filings_df, 0, 1000)
market_trend2 = get_ymarket_cap(sec_filings_df, 1000, 2000)
market_trend3 = get_ymarket_cap(sec_filings_df, 2000, 3000)
market_trend4 = get_ymarket_cap(sec_filings_df, 3000, 4180)
market_trend5 = get_ymarket_cap(sec_filings_df, 4180, 5100)
market_trend6 = get_ymarket_cap(sec_filings_df, 5100, distinct_tickers.count())

# %% [markdown]
# ##### Save market cap batch data in tables and unify them into one spark dataframe

# %%
market_trend1.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend1")
market_trend2.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend2")
market_trend3.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend3")
market_trend4.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend4")
market_trend5.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend5")
market_trend6.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_trend6")

# %%
market_cap = spark.read.table("workspace.sec_filings.market_trend1")\
                .unionByName(spark.read.table("workspace.sec_filings.market_trend2")\
                .unionByName(spark.read.table("workspace.sec_filings.market_trend3"))\
                .unionByName(spark.read.table("workspace.sec_filings.market_trend4"))\
                .unionByName(spark.read.table("workspace.sec_filings.market_trend5"))\
                .unionByName(spark.read.table("workspace.sec_filings.market_trend6"))\
                .distinct())

market_cap = market_cap.where(F.col("market_cap").isNotNull())
display(market_cap)

# %% [markdown]
# ##### Select only the top 100 companies by the highest market cap and save the dataframe in a table

# %%
market_cap_top100 = market_cap.orderBy(F.desc("market_cap")).limit(100)
display(market_cap_top100)

# %%
# save the market cap data in a delta table
market_cap.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_cap")

# save the market cap data of the top 100 companies with the highest market cap value in a delta table
market_cap_top100.write.format("delta").mode("overwrite").saveAsTable("sec_filings.market_cap_top100")

# %% [markdown]
# ##### Join the top 100 companies' market data with the filing data and save the final dataframe in a table

# %%
# join data and filter top 100 companies filing data
top100_comp_sec_filings = sec_filings_df\
                            .join(market_cap_top100, on = "tickers", how = "inner")\
                            .orderBy(F.desc("market_cap"))
display(top100_comp_sec_filings)

# %%
# save data in a table
top100_comp_sec_filings.write.format("delta").mode("overwrite").saveAsTable("sec_filings.top100_comp_sec_filings")
